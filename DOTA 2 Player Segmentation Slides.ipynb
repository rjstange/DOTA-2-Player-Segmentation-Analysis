# %%
# Source:
# http://blog.nextgenetics.net/?e=102
from IPython.display import HTML

HTML('''<script>
code_show=true; 
function code_toggle() {
 if (code_show){
 $('div.input').hide();
 } else {
 $('div.input').show();
 }
 code_show = !code_show
} 
$( document ).ready(code_toggle);
</script>
The raw code for this IPython notebook is by default hidden for easier reading.
To toggle on/off the raw code, click <a href="javascript:code_toggle()">here</a>.''')
# Out:
# <script>
# code_show=true;
# function code_toggle() {
#  if (code_show){
#  $('div.input').hide();
#  } else {
#  $('div.input').show();
#  }
#  code_show = !code_show
# }
# $( document ).ready(code_toggle);
# </script>
# The raw code for this IPython notebook is by default hidden for easier reading.
# To toggle on/off the raw code, click <a href="javascript:code_toggle()">here</a>.

# %% [markdown]
# # DOTA 2 Player Segmentation through Unsupervised Learning
# ## Riley Stange
# ### Thinkful Data Science Capstone 3: Unsupervised Learning
# #### December 2019

# %% [markdown]
# <img src="https://image.flaticon.com/icons/png/512/588/588267.png">

# %% [markdown]
# * The goal of this project is to take very detailed player gameplay statistics from Defense of The Ancients 2 (DOTA 2), and create clusters of player segmentations.
# * DOTA 2 is a Multiplayer Online Battle Arena (MOBA) game, where two teams of 5 players have the goal of destroying the opposing team's "ancient," a stationary structure that is within each team's base, at opposite sides of the map. Each team has neverending waves of "minions," or computer controlled characters that continue to go down the three lanes, and, if the players were to not interfere, would end up in a deadlock at the center point of each lane.
# * Players take turns at random choosing one character from an extensive roster of 119 (as of writing) characters, known as "heroes." When a player chooses a hero, no one else in the game can play as a copy of that character, as one could in some other similar games.

# %%
import numpy as np
import pandas as pd
from pandas.io.json import json_normalize
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA
from sklearn.cluster import KMeans, AgglomerativeClustering, DBSCAN
from hdbscan import HDBSCAN
from sklearn.manifold import TSNE
from umap import UMAP
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn import metrics
import warnings

sns.set_context("talk", font_scale=1.5)
warnings.filterwarnings("ignore")

# %% [markdown]
# # Data Exploration and Cleaning
# <img src="https://d2sbsqqdu2ofn4.cloudfront.net/media/images/Morph_350px.max-400x400.png">

# %% [markdown]
# * The data was gathered from [OpenDota's second data dump](https://blog.opendota.com/2017/03/24/datadump2/), downloaded from their small subsample that they linked, which is originally comprised of a 4GB file, containing match information, and a 1GB file containing the skill rank of the matches, with the match id, so that it can be merged with the match data for further filtering.
# * This is how I loaded and filtered my data from a 4GB file that would've otherwise crashed my machine.
# * I then appended these files into one dataframe
# * I then did the same for the file containing match_id and skill bracket, 2 being the highest, which is what I desire for my project.
# * Now with the data I then performed an inner merge function to combine the two dataframes into one, using match_id as the key
# * And for later use, I wrote the result of the dataframe to a new CSV file, allowing me to dispose of all the small CSV files I generated earlier.

# %% [markdown]
# ```
# i = 1
# for chunk in pd.read_csv(
#     "~\projects\Dota 2\player_matches_small.csv", chunksize=2500000, low_memory=False
# ):
#     chunk = chunk.loc[chunk["ability_uses"].notnull()].drop("account_id", 1)
#     chunk.to_csv("~\projects\Dota 2\player_stats{}.csv".format(i), index=False)
#     i += 1
#
# player_stats = pd.DataFrame()
#
# while i > 0:
#     player_stats = player_stats.append(
#         pd.read_csv(
#             "~\projects\Dota 2\player_stats{}.csv".format(i)
#         )
#     )
#     i -= 1
#
# i = 1
# for chunk in pd.read_csv("~\projects\Dota 2\match_skill.csv", chunksize=2500000):
#     chunk = chunk.loc[chunk['skill'] == 2]
#     chunk.to_csv("~\projects\Dota 2\match_skill{}.csv".format(i), index=False)
#     i += 1
#
# high_skill = pd.DataFrame()
#
# while i > 0:
#     high_skill = high_skill.append(
#         pd.read_csv(
#             "~\projects\Dota 2\match_skill{}.csv".format(i)
#         )
#     )
#     i -= 1
#
# skilled_player_matches = pd.merge(left=high_skill, right=player_stats, on="match_id")
#
# skilled_player_matches.to_csv("~\projects\Dota 2\skilled_player_matches.csv", index=False)
# ```

# %%
skilled_player_stats = pd.read_csv("~\projects\Dota 2\skilled_player_matches.csv")

# %%
def bighist(data, title):
    plt.figure(figsize=(20, 17))
    sns.distplot(data)
    plt.title(title, fontsize=30)
    plt.xticks(fontsize=20)
    plt.yticks(fontsize=20)
    plt.xlim(data.min(), data.max())
    plt.xlabel("")
    plt.show()
    
bighist(skilled_player_stats['kills'], "Kills")

# %%
bighist(skilled_player_stats['deaths'], "Deaths")

# %%
bighist(skilled_player_stats['assists'], "Assists")

# %%
bighist(skilled_player_stats['leaver_status'], "Leaver Status")

# %%
bighist(skilled_player_stats['gold'], "Total Gold")

# %%
bighist(skilled_player_stats['last_hits'], "Last Hits")

# %%
bighist(skilled_player_stats['denies'], "Denials")

# %%
bighist(skilled_player_stats['gold_per_min'], "Gold per/minute")

# %%
bighist(skilled_player_stats['xp_per_min'], "Experience per/minute")

# %%
bighist(skilled_player_stats['gold_spent'], "Gold Spent")

# %%
bighist(skilled_player_stats['hero_damage'], "Damage to Heroes (players)")

# %%
bighist(skilled_player_stats['tower_damage'], "Damage to Towers")

# %%
bighist(skilled_player_stats['level'], "Level at End Game")

# %%
bighist(skilled_player_stats['stuns'].fillna(0), "Total Seconds of Stun Caused")

# %% [markdown]
# * **Leaver Status** The different numbers indicate how the player left the game. 1 is where they disconnected, but reconnected within 5 minutes of disconnection, 2 is where they disconnected and didn't come back within 5 minutes of disconnecting, 3 is where they actually pressed the "Quit" button, and 4 is where they stayed connected to the game, but didn't actively participate.

# %%
skilled_player_stats[skilled_player_stats.columns[24:40]]
# Out:
#      additional_units      stuns  \
# 0                 NaN   83.22880
# 1                 NaN   14.45050
# 2                 NaN  126.21900
# 3                 NaN   25.36180
# 4                 NaN        NaN
# ...               ...        ...
# 9284              NaN    8.69707
# 9285              NaN  111.68000
# 9286              NaN    5.17055
# 9287              NaN        NaN
# 9288              NaN    2.13870
#
#                                            max_hero_hit  \
# 0     {"type":"max_hero_hit","time":1498,"max":true,...
# 1     {"type":"max_hero_hit","time":2657,"max":true,...
# 2     {"type":"max_hero_hit","time":3011,"max":true,...
# 3     {"type":"max_hero_hit","time":2840,"max":true,...
# 4     {"type":"max_hero_hit","time":2638,"max":true,...
# ...                                                 ...
# 9284  {"type":"max_hero_hit","time":2559,"max":true,...
# 9285  {"type":"max_hero_hit","time":2448,"max":true,...
# 9286  {"type":"max_hero_hit","time":2745,"max":true,...
# 9287  {"type":"max_hero_hit","time":2191,"max":true,...
# 9288  {"type":"max_hero_hit","time":2631,"max":true,...
#
#                                                   times  \
# 0     {0,60,120,180,240,300,360,420,480,540,600,660,...
# 1     {0,60,120,180,240,300,360,420,480,540,600,660,...
# 2     {0,60,120,180,240,300,360,420,480,540,600,660,...
# 3     {0,60,120,180,240,300,360,420,480,540,600,660,...
# 4     {0,60,120,180,240,300,360,420,480,540,600,660,...
# ...                                                 ...
# 9284  {0,60,120,180,240,300,360,420,480,540,600,660,...
# 9285  {0,60,120,180,240,300,360,420,480,540,600,660,...
# 9286  {0,60,120,180,240,300,360,420,480,540,600,660,...
# 9287  {0,60,120,180,240,300,360,420,480,540,600,660,...
# 9288  {0,60,120,180,240,300,360,420,480,540,600,660,...
#
#                                                  gold_t  \
# 0     {1,147,247,405,545,725,826,968,1300,1559,1872,...
# 1     {1,277,543,888,1150,1417,1712,2087,2356,2784,3...
# 2     {1,101,287,430,530,671,1055,1203,1343,1649,179...
# 3     {1,404,504,650,790,913,1110,1395,1856,2115,249...
# 4     {1,201,378,646,787,924,1066,1251,1442,1819,208...
# ...                                                 ...
# 9284  {0,237,423,646,946,1151,1251,1742,2340,2440,31...
# 9285  {0,139,531,631,860,1007,1401,1629,1982,2082,22...
# 9286  {0,136,312,530,831,1256,1587,2368,2636,3047,36...
# 9287  {0,221,488,726,826,1081,1351,1475,1666,1816,21...
# 9288  {0,140,876,976,1310,1674,2360,2670,3073,3383,3...
#
#                                                    lh_t  \
# 0     {0,0,0,0,1,3,3,4,9,9,12,18,18,20,22,25,31,31,3...
# 1     {0,3,7,9,13,17,20,23,27,31,36,36,37,40,41,45,5...
# 2     {0,0,2,3,3,4,7,8,9,14,15,18,18,23,25,27,29,31,...
# 3     {0,0,0,0,2,3,3,3,5,5,6,9,9,13,16,18,18,18,19,1...
# 4     {0,0,2,6,7,8,9,11,13,16,20,24,28,32,35,35,37,3...
# ...                                                 ...
# 9284  {0,1,3,6,11,11,11,15,20,20,24,31,38,39,41,44,4...
# 9285  {0,1,1,1,4,5,5,5,7,7,9,10,10,11,11,12,13,17,24...
# 9286  {0,1,3,6,7,7,11,12,12,12,16,21,25,25,33,33,35,...
# 9287  {0,1,6,10,10,17,23,24,26,28,36,48,54,59,67,73,...
# 9288  {0,1,4,4,4,10,13,16,17,22,27,31,36,41,50,53,61...
#
#                                                    xp_t  \
# 0     {0,123,176,449,540,719,954,1149,1419,1532,1932...
# 1     {0,123,331,604,942,1121,1413,2063,2605,2831,31...
# 2     {0,0,277,535,700,844,1386,1520,1706,2243,2325,...
# 3     {0,103,187,307,408,502,712,1073,1676,1862,2262...
# 4     {0,255,668,1163,1225,1633,1973,2219,2489,2695,...
# ...                                                 ...
# 9284  {0,255,564,812,1493,2014,2127,2751,3279,3403,4...
# 9285  {0,62,488,488,901,1171,1683,1956,2504,2597,273...
# 9286  {0,186,640,1032,1353,1590,2007,2578,2774,3085,...
# 9287  {0,141,392,580,580,881,1210,1377,1537,1598,201...
# 9288  {0,124,550,1004,1119,1389,1901,2316,2512,2909,...
#
#                                                 obs_log  \
# 0     {"{\"time\":81,\"key\":[172,106]}","{\"time\":...
# 1                                                    {}
# 2     {"{\"time\":15,\"key\":[156,96]}","{\"time\":7...
# 3     {"{\"time\":-29,\"key\":[148,104]}","{\"time\"...
# 4                                                    {}
# ...                                                 ...
# 9284                                                 {}
# 9285  {"{\"time\":11,\"key\":[117,125]}","{\"time\":...
# 9286               {"{\"time\":536,\"key\":[111,130]}"}
# 9287  {"{\"time\":1829,\"key\":[148,106]}","{\"time\...
# 9288                                                 {}
#
#                                                 sen_log  \
# 0     {"{\"time\":2055,\"key\":[132,104]}","{\"time\...
# 1                                                    {}
# 2                                                    {}
# 3                                                    {}
# 4     {"{\"time\":800,\"key\":[140,90]}","{\"time\":...
# ...                                                 ...
# 9284                                                 {}
# 9285  {"{\"time\":728,\"key\":[117,155]}","{\"time\"...
# 9286                                                 {}
# 9287  {"{\"time\":1827,\"key\":[148,106]}","{\"time\...
# 9288                                                 {}
#
#                                            purchase_log  \
# 0     {"{\"time\":-83,\"key\":\"tango\"}","{\"time\"...
# 1     {"{\"time\":-69,\"key\":\"stout_shield\"}","{\...
# 2     {"{\"time\":-67,\"key\":\"tango\"}","{\"time\"...
# 3     {"{\"time\":-87,\"key\":\"courier\"}","{\"time...
# 4     {"{\"time\":-71,\"key\":\"ward_sentry\"}","{\"...
# ...                                                 ...
# 9284  {"{\"time\":-66,\"key\":\"tango\"}","{\"time\"...
# 9285  {"{\"time\":-52,\"key\":\"courier\"}","{\"time...
# 9286  {"{\"time\":-39,\"key\":\"gauntlets\"}","{\"ti...
# 9287  {"{\"time\":-59,\"key\":\"quelling_blade\"}","...
# 9288  {"{\"time\":-46,\"key\":\"slippers\"}","{\"tim...
#
#                                               kills_log          buyback_log  \
# 0     {"{\"time\":1475,\"key\":\"npc_dota_hero_huska...                   {}
# 1     {"{\"time\":131,\"key\":\"npc_dota_hero_arc_wa...                   {}
# 2     {"{\"time\":660,\"key\":\"npc_dota_hero_ancien...                   {}
# 3     {"{\"time\":41,\"key\":\"npc_dota_hero_arc_war...                   {}
# 4     {"{\"time\":875,\"key\":\"npc_dota_hero_huskar...  {"{\"time\":2748}"}
# ...                                                 ...                  ...
# 9284  {"{\"time\":404,\"key\":\"npc_dota_hero_crysta...                   {}
# 9285  {"{\"time\":710,\"key\":\"npc_dota_hero_sven\"...                   {}
# 9286  {"{\"time\":292,\"key\":\"npc_dota_hero_spectr...  {"{\"time\":2798}"}
# 9287  {"{\"time\":897,\"key\":\"npc_dota_hero_bristl...                   {}
# 9288  {"{\"time\":115,\"key\":\"npc_dota_hero_bristl...                   {}
#
#                                                lane_pos  \
# 0     {"70":{"76":9},"72":{"72":10,"74":5,"78":2,"80...
# 1     {"72":{"76":3},"74":{"76":13},"76":{"76":24,"7...
# 2     {"152":{"130":1},"154":{"128":1,"132":1,"136":...
# 3     {"72":{"76":25},"74":{"74":1,"76":11,"78":1},"...
# 4     {"70":{"74":39,"160":6},"72":{"76":3,"160":7,"...
# ...                                                 ...
# 9284  {"147":{"118":1,"119":6},"148":{"116":1,"117":...
# 9285  {"73":{"161":1,"163":1},"74":{"160":1,"164":1}...
# 9286  {"77":{"163":1,"165":6,"166":4,"167":31},"78":...
# 9287  {"81":{"152":1,"154":1},"82":{"169":1,"172":1}...
# 9288  {"72":{"161":1},"73":{"158":1,"161":1,"162":1,...
#
#                                                     obs  \
# 0                     {"108":{"128":1},"172":{"106":1}}
# 1                                                    {}
# 2     {"118":{"94":1},"140":{"90":2},"146":{"92":1,"...
# 3     {"92":{"122":1,"124":1},"116":{"92":2,"94":1},...
# 4                                                    {}
# ...                                                 ...
# 9284                                                 {}
# 9285  {"77":{"133":1},"91":{"161":1},"105":{"112":1}...
# 9286                                  {"111":{"130":1}}
# 9287                   {"115":{"93":1},"148":{"106":1}}
# 9288                                                 {}
#
#                                    sen  \
# 0      {"94":{"96":1},"132":{"104":1}}
# 1                                   {}
# 2                                   {}
# 3                                   {}
# 4     {"140":{"90":1},"178":{"104":1}}
# ...                                ...
# 9284                                {}
# 9285         {"117":{"125":1,"155":1}}
# 9286                                {}
# 9287  {"115":{"93":1},"148":{"106":1}}
# 9288                                {}
#
#                                                 actions
# 0     {"1":8243,"2":256,"3":41,"4":464,"5":86,"6":10...
# 1     {"1":5342,"2":1,"3":113,"4":942,"5":14,"6":72,...
# 2     {"1":6144,"2":108,"3":105,"4":231,"5":106,"6":...
# 3     {"1":4386,"2":3,"4":1165,"5":156,"6":64,"7":4,...
# 4     {"1":5422,"2":241,"3":1,"4":1005,"5":42,"6":59...
# ...                                                 ...
# 9284                                                NaN
# 9285                                                NaN
# 9286                                                NaN
# 9287                                                NaN
# 9288                                                NaN
#
# [9289 rows x 16 columns]

# %% [markdown]
# The rest of the features in the dataset are comprised seemingly non-numerical features. Here's an example of what they contain.

# %%
skilled_player_stats[skilled_player_stats.columns[-16:]]
# Out:
#          pings                                           purchase  \
# 0     {"0":29}  {"tango":1,"flask":1,"ward_observer":2,"clarit...
# 1     {"0":52}  {"stout_shield":1,"quelling_blade":1,"tango":1...
# 2     {"0":28}  {"tango":1,"flask":1,"clarity":2,"boots":1,"wa...
# 3     {"0":21}  {"courier":1,"clarity":1,"tango":1,"ward_obser...
# 4     {"0":15}  {"ward_sentry":1,"tango":1,"stout_shield":1,"s...
# ...        ...                                                ...
# 9284   {"0":4}  {"tango":1,"stout_shield":1,"ring_of_protectio...
# 9285  {"0":10}  {"courier":1,"tango":1,"flask":1,"clarity":2,"...
# 9286  {"0":14}  {"gauntlets":2,"clarity":1,"flask":1,"tango":1...
# 9287  {"0":49}  {"quelling_blade":1,"stout_shield":1,"tango":1...
# 9288  {"0":68}  {"slippers":1,"tango":1,"clarity":1,"magic_sti...
#
#                                            gold_reasons  \
# 0     {"0":914,"1":-3351,"6":344,"11":2418,"12":7232...
# 1     {"0":712,"1":-3143,"6":1225,"11":2478,"12":703...
# 2     {"0":955,"1":-4790,"6":25,"11":1283,"12":8944,...
# 3     {"0":625,"1":-3410,"6":1115,"11":2419,"12":721...
# 4     {"0":882,"1":-4161,"2":-1651,"6":492,"11":2808...
# ...                                                 ...
# 9284  {"0":1431,"6":750,"11":4430,"12":4149,"13":564...
# 9285  {"0":778,"1":-1315,"6":62,"11":4105,"12":5329,...
# 9286  {"0":1211,"1":-3802,"2":-1399,"6":550,"11":381...
# 9287  {"0":1287,"1":-2902,"6":212,"11":4939,"12":488...
# 9288  {"0":1164,"1":-2605,"6":1182,"11":4915,"12":83...
#
#                                    xp_reasons  \
# 0               {"0":490,"1":15563,"2":13076}
# 1               {"0":158,"1":19782,"2":13381}
# 2                {"0":607,"1":18052,"2":9048}
# 3                 {"0":47,"1":14554,"2":9068}
# 4               {"0":437,"1":19292,"2":13003}
# ...                                       ...
# 9284  {"0":1079,"1":12797,"2":13517,"3":1847}
# 9285    {"0":720,"1":12090,"2":9156,"3":1251}
# 9286    {"0":1042,"1":12615,"2":7278,"3":953}
# 9287   {"0":1057,"1":10529,"2":14340,"3":953}
# 9288   {"0":1060,"1":14303,"2":15978,"3":357}
#
#                                                  killed  \
# 0     {"npc_dota_creep_badguys_melee":114,"npc_dota_...
# 1     {"npc_dota_creep_badguys_melee":121,"npc_dota_...
# 2     {"npc_dota_creep_goodguys_melee":51,"npc_dota_...
# 3     {"npc_dota_hero_arc_warden":2,"npc_dota_creep_...
# 4     {"npc_dota_creep_goodguys_melee":2,"npc_dota_c...
# ...                                                 ...
# 9284  {"npc_dota_creep_badguys_melee":3,"npc_dota_cr...
# 9285  {"npc_dota_creep_goodguys_melee":36,"npc_dota_...
# 9286  {"npc_dota_creep_goodguys_melee":39,"npc_dota_...
# 9287  {"npc_dota_neutral_forest_troll_high_priest":2...
# 9288  {"npc_dota_creep_goodguys_melee":183,"npc_dota...
#
#                                               item_uses  \
# 0     {"tango":4,"clarity":1,"ward_observer":2,"magi...
# 1     {"tango":4,"branches":1,"phase_boots":119,"fla...
# 2     {"ward_observer":6,"tango":4,"flask":1,"clarit...
# 3     {"courier":1,"ward_observer":15,"tango":4,"cla...
# 4     {"tango":4,"flask":1,"ring_of_aquila":6,"power...
# ...                                                 ...
# 9284  {"tango":4,"clarity":2,"ring_of_basilius":1,"t...
# 9285  {"courier":1,"ward_observer":13,"flask":1,"tps...
# 9286  {"tango":4,"clarity":1,"flask":1,"tango_single...
# 9287  {"tango":4,"tpscroll":3,"power_treads":14,"bla...
# 9288  {"tango":4,"magic_stick":9,"clarity":1,"tpscro...
#
#                                            ability_uses  \
# 0     {"sandking_burrowstrike":74,"sandking_sand_sto...
# 1     {"life_stealer_open_wounds":26,"life_stealer_r...
# 2     {"nyx_assassin_spiked_carapace":32,"nyx_assass...
# 3     {"ancient_apparition_chilling_touch":22,"ancie...
# 4     {"riki_smoke_screen":30,"riki_blink_strike":42...
# ...                                                 ...
# 9284  {"abaddon_aphotic_shield":41,"abaddon_death_co...
# 9285  {"winter_wyvern_arctic_burn":28,"winter_wyvern...
# 9286  {"night_stalker_void":52,"night_stalker_darkne...
# 9287  {"bloodseeker_bloodrage":115,"bloodseeker_rupt...
# 9288  {"morphling_morph_agi":28,"morphling_waveform"...
#
#                                               hero_hits  \
# 0     {"undefined":62,"sandking_burrowstrike":43,"an...
# 1     {"ancient_apparition_chilling_touch":16,"undef...
# 2     {"undefined":32,"nyx_assassin_spiked_carapace"...
# 3     {"undefined":56,"ancient_apparition_chilling_t...
# 4     {"undefined":144,"riki_blink_strike":27,"ancie...
# ...                                                 ...
# 9284  {"undefined":112,"abaddon_aphotic_shield":29,"...
# 9285  {"undefined":71,"winter_wyvern_arctic_burn":82...
# 9286  {"night_stalker_void":49,"undefined":112,"arml...
# 9287  {"undefined":55,"bloodseeker_rupture":112,"blo...
# 9288  {"undefined":117,"morphling_waveform":30,"morp...
#
#                                                  damage  \
# 0     {"npc_dota_hero_nyx_assassin":5891,"npc_dota_h...
# 1     {"npc_dota_hero_arc_warden":3993,"npc_dota_cre...
# 2     {"npc_dota_hero_sand_king":3860,"npc_dota_cree...
# 3     {"npc_dota_hero_arc_warden":3607,"npc_dota_cre...
# 4     {"npc_dota_creep_badguys_melee":42584,"npc_dot...
# ...                                                 ...
# 9284  {"npc_dota_creep_badguys_melee":471,"npc_dota_...
# 9285  {"npc_dota_hero_sven":3176,"npc_dota_hero_bris...
# 9286  {"npc_dota_creep_badguys_melee":63,"npc_dota_c...
# 9287  {"npc_dota_neutral_forest_troll_high_priest":1...
# 9288  {"npc_dota_creep_goodguys_melee":104103,"npc_d...
#
#                                            damage_taken  \
# 0     {"npc_dota_hero_nyx_assassin":3860,"npc_dota_c...
# 1     {"npc_dota_creep_badguys_ranged":2143,"npc_dot...
# 2     {"npc_dota_hero_sand_king":5891,"npc_dota_hero...
# 3     {"npc_dota_creep_badguys_melee":825,"npc_dota_...
# 4     {"npc_dota_hero_dragon_knight":4917,"npc_dota_...
# ...                                                 ...
# 9284  {"npc_dota_creep_goodguys_ranged":928,"npc_dot...
# 9285  {"npc_dota_creep_goodguys_melee":778,"npc_dota...
# 9286  {"npc_dota_hero_tinker":8796,"npc_dota_creep_g...
# 9287  {"npc_dota_neutral_forest_troll_high_priest":6...
# 9288  {"npc_dota_creep_goodguys_melee":1972,"npc_dot...
#
#                                        damage_inflictor  \
# 0     {"undefined":4170,"sandking_burrowstrike":8093...
# 1     {"ancient_apparition_chilling_touch":767,"unde...
# 2     {"undefined":1618,"nyx_assassin_spiked_carapac...
# 3     {"undefined":2674,"ancient_apparition_chilling...
# 4     {"undefined":21586,"riki_blink_strike":1474,"a...
# ...                                                 ...
# 9284  {"undefined":9879,"abaddon_aphotic_shield":310...
# 9285  {"undefined":3430,"winter_wyvern_arctic_burn":...
# 9286      {"night_stalker_void":9213,"undefined":10750}
# 9287  {"undefined":8600,"bloodseeker_rupture":3850,"...
# 9288  {"undefined":9358,"morphling_waveform":6186,"m...
#
#                                 runes  \
# 0                             {"5":2}
# 1     {"1":1,"2":1,"3":1,"4":1,"5":1}
# 2                       {"3":1,"5":2}
# 3                                  {}
# 4                       {"2":1,"5":2}
# ...                               ...
# 9284                    {"3":1,"5":2}
# 9285                    {"4":1,"5":1}
# 9286  {"1":3,"2":2,"3":1,"4":1,"5":5}
# 9287              {"0":1,"1":1,"5":2}
# 9288                    {"2":1,"5":1}
#
#                                               killed_by  \
# 0     {"npc_dota_hero_huskar":1,"npc_dota_badguys_to...
# 1     {"npc_dota_badguys_tower2_bot":1,"npc_dota_cre...
# 2     {"npc_dota_hero_chaos_knight":4,"npc_dota_hero...
# 3     {"npc_dota_hero_huskar":1,"npc_dota_hero_nyx_a...
# 4     {"npc_dota_hero_arc_warden":1,"npc_dota_hero_l...
# ...                                                 ...
# 9284                                                 {}
# 9285  {"npc_dota_hero_bristleback":1,"npc_dota_hero_...
# 9286  {"npc_dota_hero_sven":2,"npc_dota_hero_tinker"...
# 9287  {"npc_dota_hero_sven":1,"npc_dota_hero_bristle...
# 9288  {"npc_dota_hero_sven":1,"npc_dota_hero_crystal...
#
#                                      kill_streaks    multi_kills  \
# 0                                         {"3":1}  {"2":1,"3":1}
# 1                                              {}        {"2":1}
# 2                                         {"3":1}             {}
# 3                                              {}             {}
# 4                                         {"3":2}        {"2":1}
# ...                                           ...            ...
# 9284                                {"3":1,"4":1}             {}
# 9285                                      {"3":1}             {}
# 9286              {"3":3,"4":1,"5":1,"6":1,"7":1}        {"2":2}
# 9287                          {"3":1,"4":1,"5":1}        {"2":2}
# 9288  {"3":3,"4":3,"5":3,"6":1,"7":1,"8":1,"9":1}        {"2":2}
#
#                      life_state
# 0     {"0":2769,"1":16,"2":447}
# 1     {"0":2805,"1":24,"2":403}
# 2     {"0":2584,"1":25,"2":623}
# 3      {"0":2757,"1":8,"2":467}
# 4     {"0":2739,"1":12,"2":481}
# ...                         ...
# 9284                        NaN
# 9285                        NaN
# 9286                        NaN
# 9287                        NaN
# 9288                        NaN
#
# [9289 rows x 16 columns]

# %% [markdown]
# So, all 31 of these object columns contain dictionaries with various numerical values. As you will see, these will cause a lot of dimensionality when I make use of the json_normalize function.

# %% [markdown]
# # The Naive Approach
# <img src="https://steamcdn-a.akamaihd.net/apps/dota2/images/winter2019/combo.png">

# %% [markdown]
# * First, I dropped the "times" and columns ending with "_t", and all of the "_log" columns, as well as "actions", "additional_units" and "life_state," as I was having trouble normalizing them, and felt like I had plenty to work with already.
# * Now time to see what happens when we try to expand out the dictionaries keys into their own columns, with the values becoming the rows under those new columns.

# %%
skilled_player_stats_naive = skilled_player_stats.drop(
    columns=["actions", "additional_units", "times", 
             "gold_t", "lh_t", "xp_t", "max_hero_hit", 
             "obs_log", "sen_log", "purchase_log", 
             "kills_log", "buyback_log", "life_state"])

# %%
skilled_player_stats_naive = pd.concat(
    [
        skilled_player_stats_naive,
        json_normalize(skilled_player_stats["lane_pos"].map(eval)).add_prefix(
            "lane_pos_"
        ),
        json_normalize(skilled_player_stats["obs"].map(eval)).add_prefix("obs_"),
        json_normalize(skilled_player_stats["killed"].map(eval)).add_prefix("killed_"),
        json_normalize(skilled_player_stats["item_uses"].map(eval)).add_prefix("used_"),
        json_normalize(skilled_player_stats["sen"].map(eval)).add_prefix("sen_"),
        json_normalize(skilled_player_stats["purchase"].map(eval)).add_prefix(
            "purchased_"
        ),
        json_normalize(skilled_player_stats["gold_reasons"].map(eval)).add_prefix(
            "gold_"
        ),
        json_normalize(skilled_player_stats["xp_reasons"].map(eval)).add_prefix("xp_"),
        json_normalize(skilled_player_stats["ability_uses"].map(eval)).add_prefix(
            "used_"
        ),
        json_normalize(skilled_player_stats["hero_hits"].map(eval)).add_prefix(
            "hero_hits_"
        ),
        json_normalize(skilled_player_stats["damage"].map(eval)).add_prefix("damage_"),
        json_normalize(skilled_player_stats["damage_taken"].map(eval)).add_prefix(
            "damaged_by_"
        ),
        json_normalize(skilled_player_stats["damage_inflictor"].map(eval)).add_prefix(
            "damaged_inflictor_"
        ),
        json_normalize(skilled_player_stats["runes"].map(eval)).add_prefix("runes_"),
        json_normalize(skilled_player_stats["killed_by"].map(eval)).add_prefix(
            "killed_by_"
        ),
        json_normalize(skilled_player_stats["kill_streaks"].map(eval)).add_prefix(
            "kill_streaks_"
        ),
        json_normalize(skilled_player_stats["multi_kills"].map(eval)).add_prefix(
            "multi_kills_"
        ),
        json_normalize(skilled_player_stats["pings"].map(eval)).add_prefix("pings"),
    ],
    axis=1,
)

# %%
skilled_player_stats_naive = skilled_player_stats_naive.drop(
    columns=[
        "sen",
        "pings",
        "multi_kills",
        "kill_streaks",
        "killed_by",
        "runes",
        "damage_inflictor",
        "damage_taken",
        "damage",
        "hero_hits",
        "ability_uses",
        "xp_reasons",
        "gold_reasons",
        "purchase",
        "item_uses",
        "killed",
        "obs",
        "lane_pos",
    ]
)

# %%
skilled_player_stats_naive = skilled_player_stats_naive.fillna(0)

# %%
X = skilled_player_stats_naive.drop(
    columns=["match_id", "hero_id", 
             "skill", "player_slot"]
)

# %%
non_pca_cols = list(X[X.columns[:21]].columns)

# %%
non_pca_cols.append("pings0")

# %%
non_pca_cols
# Out:
# ['item_0',
#  'item_1',
#  'item_2',
#  'item_3',
#  'item_4',
#  'item_5',
#  'kills',
#  'deaths',
#  'assists',
#  'leaver_status',
#  'gold',
#  'last_hits',
#  'denies',
#  'gold_per_min',
#  'xp_per_min',
#  'gold_spent',
#  'hero_damage',
#  'tower_damage',
#  'hero_healing',
#  'level',
#  'stuns',
#  'pings0']

# %%
scaler = StandardScaler()
X_std = scaler.fit_transform(X.drop(columns=non_pca_cols))

# %%
pca = PCA(n_components=34)
X_pca = pca.fit_transform(X_std)

# %% [markdown]
# <img src="https://i.pinimg.com/originals/52/91/7e/52917e8f5c07b77b0d5ff6490e4c73fc.png" width="500">

# %% [markdown]
# # IT'S OVER 9000!

# %% [markdown]
# # Columns: 11772

# %% [markdown]
# # Dimensionality Reduction Used:

# %% [markdown]
# For my PCA I used 34 components only on the over 11 thousand columns, leaving 22 of the other numeric columns I showed earlier,  so I will have a total of 56 dimensions, just like I ended up with in my "Informed Approach" that I will show later.

# %% [markdown]
# ## PCA: 34 Components

# %% [markdown]
# ## Sum of Explained Variance Ratio:

# %%
pca.explained_variance_ratio_.sum()
# Out:
# 0.2673026871243633

# %%
X_pca = pd.concat([X[non_pca_cols], pd.DataFrame(X_pca)], axis=1)

# %%
X_pca = scaler.fit_transform(X_pca)

# %% [markdown]
# ### Clustering

# %% [markdown]
# #### K-Means: 5 Clusters

# %%
kmeans = KMeans(n_clusters=5)

# %%
kmeans.fit(X_pca)
# Out:
# KMeans(algorithm='auto', copy_x=True, init='k-means++', max_iter=300,
#        n_clusters=5, n_init=10, n_jobs=None, precompute_distances='auto',
#        random_state=None, tol=0.0001, verbose=0)

# %%
y_pred = kmeans.predict(X_pca)

# %% [markdown]
# ### Silhouette Score:

# %%
print(metrics.silhouette_score(X_pca, y_pred, metric='euclidean'))
# Out:
# 0.08972787266227564

# %% [markdown]
# ##### Visualization

# %% [markdown]
# ##### PCA

# %%
pca = PCA(n_components=2)
pca_results = pd.DataFrame(pca.fit_transform(X_pca))

# %%
plt.scatter(x=pca_results[0], y=pca_results[1], c=y_pred)
plt.colorbar()
plt.show()

# %% [markdown]
# ##### t-SNE

# %% [markdown]
# ###### perplexity=40, n_iter=300,

# %%
tsne = TSNE(n_components=2, perplexity=40, n_iter=300, verbose=1)
# %time tsne_results = pd.DataFrame(tsne.fit_transform(X_pca))
# Out:
# [t-SNE] Computing 121 nearest neighbors...
# [t-SNE] Indexed 9289 samples in 0.033s...
# [t-SNE] Computed neighbors for 9289 samples in 8.037s...
# [t-SNE] Computed conditional probabilities for sample 1000 / 9289
# [t-SNE] Computed conditional probabilities for sample 2000 / 9289
# [t-SNE] Computed conditional probabilities for sample 3000 / 9289
# [t-SNE] Computed conditional probabilities for sample 4000 / 9289
# [t-SNE] Computed conditional probabilities for sample 5000 / 9289
# [t-SNE] Computed conditional probabilities for sample 6000 / 9289
# [t-SNE] Computed conditional probabilities for sample 7000 / 9289
# [t-SNE] Computed conditional probabilities for sample 8000 / 9289
# [t-SNE] Computed conditional probabilities for sample 9000 / 9289
# [t-SNE] Computed conditional probabilities for sample 9289 / 9289
# [t-SNE] Mean sigma: 1.360308
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 91.331055
# [t-SNE] KL divergence after 300 iterations: 3.531728
# Wall time: 40.7 s

# %%
plt.scatter(x=tsne_results[0], y=tsne_results[1], c=y_pred)
plt.colorbar()
plt.show()

# %% [markdown]
# ##### UMAP

# %% [markdown]
# #### n_neighbors=15, min_dist=0.6

# %%
umap = UMAP(n_neighbors=15, min_dist=0.6)
# %time umap_results = pd.DataFrame(umap.fit_transform(X_pca))
# Out:
# Wall time: 19.5 s

# %%
plt.scatter(x=umap_results[0], y=umap_results[1], c=y_pred)
plt.colorbar()
plt.show()

# %% [markdown]
# ### Agglomerative: 5 Clusters

# %% [markdown]
# #### Silhouette Score:

# %%
agg_cluster = AgglomerativeClustering(n_clusters=5)

y_pred = agg_cluster.fit_predict(X_pca)

# %%
print(metrics.silhouette_score(X_pca, y_pred, metric='euclidean'))
# Out:
# 0.04640023836835955

# %% [markdown]
# #### Visualization

# %% [markdown]
# #### PCA

# %%
plt.scatter(x=pca_results[0], y=pca_results[1], c=y_pred)
plt.colorbar()
plt.show()

# %% [markdown]
# #### t-SNE

# %%
plt.scatter(x=tsne_results[0], y=tsne_results[1], c=y_pred)
plt.colorbar()
plt.show()

# %% [markdown]
# #### UMAP

# %%
plt.scatter(x=umap_results[0], y=umap_results[1], c=y_pred)
plt.colorbar()
plt.show()

# %% [markdown]
# ### HDBSCAN: Minimum Cluster Size: 5

# %%
hdbscan = HDBSCAN(min_cluster_size=5)

# %time y_pred = hdbscan.fit_predict(X_pca)
# Out:
# Wall time: 5.31 s

# %% [markdown]
# #### Silhouette Score:

# %%
print(metrics.silhouette_score(X_pca, y_pred, metric='euclidean'))
# Out:
# 0.050170157495002456

# %% [markdown]
# #### Visualization

# %% [markdown]
# ##### PCA

# %%
plt.scatter(x=pca_results[0], y=pca_results[1], c=y_pred)
plt.colorbar()
plt.show()

# %% [markdown]
# #### t-SNE

# %%
plt.scatter(x=tsne_results[0], y=tsne_results[1], c=y_pred)
plt.colorbar()
plt.show()

# %% [markdown]
# #### UMAP

# %%
plt.scatter(x=umap_results[0], y=umap_results[1], c=y_pred)
plt.colorbar()
plt.show()

# %% [markdown]
# I felt it unnecessary to comment on any of these visualizations, as they all are fairly poor and noisy, with a lot of blending. This shows that the majority of the features in the dataset are confusing the models, and need to be dealt away with.

# %% [markdown]
# # The Informed Approach
# <img src="https://i.pinimg.com/originals/9e/6a/f3/9e6af38b570b29e66d2bd0931161ab47.png">

# %% [markdown]
# First, I used the "leaver_status" feature to filter out over 1400 players that left the game at some point, or were in a game where a player left.
#
# Since the game is team based, if a team is lacking one or more players, it will make that team perform worse, and the opposing team perform better, causing the data to not be an accurate representation of a player's usual behavior and performance.

# %%
len(skilled_player_stats_informed)
# Out:
# 7794

# %%
skilled_player_stats['leaver_status'].value_counts()
# Out:
# 0.0    9004
# 1.0     187
# 3.0      48
# 2.0      41
# 4.0       9
# Name: leaver_status, dtype: int64

# %%
skilled_player_stats_informed = skilled_player_stats[
    ~skilled_player_stats["match_id"].isin( # No matches...
    skilled_player_stats[
        skilled_player_stats["leaver_status"] > 0]["match_id"])].reset_index(drop=True) # where a player left at any point

# %%
skilled_player_stats_informed = skilled_player_stats_informed.drop(
    columns=["leaver_status", "actions", "additional_units", "times", 
             "gold_t", "lh_t", "xp_t", "max_hero_hit", "obs_log", 
             "sen_log", "purchase_log", "kills_log", "buyback_log", 
             "life_state"])

# %%
skilled_player_stats_informed[skilled_player_stats_informed.columns[4:23]
                             ].head()
# Out:
#    item_0  item_1  item_2  item_3  item_4  item_5  kills  deaths  assists  \
# 0     114     108       0     180     116       1      7       9       28
# 1     112      50     158       0     154     143      8       7       26
# 2     180      36     203       0      46     108      9      10       18
# 3       0     100     123     214     232     108      7      10       31
# 4     196      63      71     139     154      30     11       9       20
#
#      gold  last_hits  denies  gold_per_min  xp_per_min  gold_spent  \
# 0   496.0        184       1           451         566     21625.0
# 1   253.0        204       9           461         647     22675.0
# 2   853.0         75       2           366         538     16430.0
# 3  1006.0         77       7           388         459     19505.0
# 4  2008.0        162       4           430         636     17620.0
#
#    hero_damage  tower_damage  hero_healing  level
# 0      15533.0         492.0           0.0     23
# 1      13802.0        1871.0        2036.0     25
# 2      12607.0         302.0           0.0     23
# 3       9431.0         448.0           0.0     21
# 4      15451.0         951.0           0.0     25

# %%
skilled_player_stats_informed[skilled_player_stats_informed.columns[23:43]
                             ].head()
# Out:
#       stuns                                           lane_pos  \
# 0   83.2288  {"70":{"76":9},"72":{"72":10,"74":5,"78":2,"80...
# 1   14.4505  {"72":{"76":3},"74":{"76":13},"76":{"76":24,"7...
# 2  126.2190  {"152":{"130":1},"154":{"128":1,"132":1,"136":...
# 3   25.3618  {"72":{"76":25},"74":{"74":1,"76":11,"78":1},"...
# 4       NaN  {"70":{"74":39,"160":6},"72":{"76":3,"160":7,"...
#
#                                                  obs  \
# 0                  {"108":{"128":1},"172":{"106":1}}
# 1                                                 {}
# 2  {"118":{"94":1},"140":{"90":2},"146":{"92":1,"...
# 3  {"92":{"122":1,"124":1},"116":{"92":2,"94":1},...
# 4                                                 {}
#
#                                 sen     pings  \
# 0   {"94":{"96":1},"132":{"104":1}}  {"0":29}
# 1                                {}  {"0":52}
# 2                                {}  {"0":28}
# 3                                {}  {"0":21}
# 4  {"140":{"90":1},"178":{"104":1}}  {"0":15}
#
#                                             purchase  \
# 0  {"tango":1,"flask":1,"ward_observer":2,"clarit...
# 1  {"stout_shield":1,"quelling_blade":1,"tango":1...
# 2  {"tango":1,"flask":1,"clarity":2,"boots":1,"wa...
# 3  {"courier":1,"clarity":1,"tango":1,"ward_obser...
# 4  {"ward_sentry":1,"tango":1,"stout_shield":1,"s...
#
#                                         gold_reasons  \
# 0  {"0":914,"1":-3351,"6":344,"11":2418,"12":7232...
# 1  {"0":712,"1":-3143,"6":1225,"11":2478,"12":703...
# 2  {"0":955,"1":-4790,"6":25,"11":1283,"12":8944,...
# 3  {"0":625,"1":-3410,"6":1115,"11":2419,"12":721...
# 4  {"0":882,"1":-4161,"2":-1651,"6":492,"11":2808...
#
#                       xp_reasons  \
# 0  {"0":490,"1":15563,"2":13076}
# 1  {"0":158,"1":19782,"2":13381}
# 2   {"0":607,"1":18052,"2":9048}
# 3    {"0":47,"1":14554,"2":9068}
# 4  {"0":437,"1":19292,"2":13003}
#
#                                               killed  \
# 0  {"npc_dota_creep_badguys_melee":114,"npc_dota_...
# 1  {"npc_dota_creep_badguys_melee":121,"npc_dota_...
# 2  {"npc_dota_creep_goodguys_melee":51,"npc_dota_...
# 3  {"npc_dota_hero_arc_warden":2,"npc_dota_creep_...
# 4  {"npc_dota_creep_goodguys_melee":2,"npc_dota_c...
#
#                                            item_uses  \
# 0  {"tango":4,"clarity":1,"ward_observer":2,"magi...
# 1  {"tango":4,"branches":1,"phase_boots":119,"fla...
# 2  {"ward_observer":6,"tango":4,"flask":1,"clarit...
# 3  {"courier":1,"ward_observer":15,"tango":4,"cla...
# 4  {"tango":4,"flask":1,"ring_of_aquila":6,"power...
#
#                                         ability_uses  \
# 0  {"sandking_burrowstrike":74,"sandking_sand_sto...
# 1  {"life_stealer_open_wounds":26,"life_stealer_r...
# 2  {"nyx_assassin_spiked_carapace":32,"nyx_assass...
# 3  {"ancient_apparition_chilling_touch":22,"ancie...
# 4  {"riki_smoke_screen":30,"riki_blink_strike":42...
#
#                                            hero_hits  \
# 0  {"undefined":62,"sandking_burrowstrike":43,"an...
# 1  {"ancient_apparition_chilling_touch":16,"undef...
# 2  {"undefined":32,"nyx_assassin_spiked_carapace"...
# 3  {"undefined":56,"ancient_apparition_chilling_t...
# 4  {"undefined":144,"riki_blink_strike":27,"ancie...
#
#                                               damage  \
# 0  {"npc_dota_hero_nyx_assassin":5891,"npc_dota_h...
# 1  {"npc_dota_hero_arc_warden":3993,"npc_dota_cre...
# 2  {"npc_dota_hero_sand_king":3860,"npc_dota_cree...
# 3  {"npc_dota_hero_arc_warden":3607,"npc_dota_cre...
# 4  {"npc_dota_creep_badguys_melee":42584,"npc_dot...
#
#                                         damage_taken  \
# 0  {"npc_dota_hero_nyx_assassin":3860,"npc_dota_c...
# 1  {"npc_dota_creep_badguys_ranged":2143,"npc_dot...
# 2  {"npc_dota_hero_sand_king":5891,"npc_dota_hero...
# 3  {"npc_dota_creep_badguys_melee":825,"npc_dota_...
# 4  {"npc_dota_hero_dragon_knight":4917,"npc_dota_...
#
#                                     damage_inflictor  \
# 0  {"undefined":4170,"sandking_burrowstrike":8093...
# 1  {"ancient_apparition_chilling_touch":767,"unde...
# 2  {"undefined":1618,"nyx_assassin_spiked_carapac...
# 3  {"undefined":2674,"ancient_apparition_chilling...
# 4  {"undefined":21586,"riki_blink_strike":1474,"a...
#
#                              runes  \
# 0                          {"5":2}
# 1  {"1":1,"2":1,"3":1,"4":1,"5":1}
# 2                    {"3":1,"5":2}
# 3                               {}
# 4                    {"2":1,"5":2}
#
#                                            killed_by kill_streaks  \
# 0  {"npc_dota_hero_huskar":1,"npc_dota_badguys_to...      {"3":1}
# 1  {"npc_dota_badguys_tower2_bot":1,"npc_dota_cre...           {}
# 2  {"npc_dota_hero_chaos_knight":4,"npc_dota_hero...      {"3":1}
# 3  {"npc_dota_hero_huskar":1,"npc_dota_hero_nyx_a...           {}
# 4  {"npc_dota_hero_arc_warden":1,"npc_dota_hero_l...      {"3":2}
#
#      multi_kills
# 0  {"2":1,"3":1}
# 1        {"2":1}
# 2             {}
# 3             {}
# 4        {"2":1}

# %% [markdown]
# # Dimensionality Check

# %% [markdown]
# ## "lane_pos"

# %%
len(json_normalize(skilled_player_stats_informed["lane_pos"].map(eval)
                  ).columns)
# Out:
# 5860

# %% [markdown]
# ## "obs"

# %%
len(json_normalize(skilled_player_stats_informed["obs"].map(eval)
                  ).columns)
# Out:
# 1169

# %% [markdown]
# ## "sen"

# %%
len(json_normalize(skilled_player_stats_informed["sen"].map(eval)
                  ).columns)
# Out:
# 1739

# %%
skilled_player_stats_informed["pings"] = json_normalize(skilled_player_stats_informed["pings"].map(eval)
                                                       )

# %%
len(json_normalize(skilled_player_stats_informed["purchase"].map(eval)
                  ).columns)
# Out:
# 196

# %%
len(json_normalize(skilled_player_stats_informed["gold_reasons"].map(eval)
                  ).columns)
# Out:
# 10

# %%
skilled_player_stats_informed = pd.concat([
    skilled_player_stats_informed,
    json_normalize(skilled_player_stats_informed["gold_reasons"].map(eval)).add_prefix("gold_reasons_")
    ], axis=1
)

# %%
len(json_normalize(skilled_player_stats_informed["xp_reasons"].map(eval)
                  ).columns)
# Out:
# 4

# %%
skilled_player_stats_informed = pd.concat([
    skilled_player_stats_informed,
    json_normalize(skilled_player_stats_informed["xp_reasons"].map(eval)).add_prefix("xp_reasons_")
    ], axis=1
)

# %%
len(json_normalize(skilled_player_stats_informed["killed"].map(eval)
                  ).columns)
# Out:
# 285

# %%
len(json_normalize(skilled_player_stats_informed["item_uses"].map(eval)
                  ).columns)
# Out:
# 82

# %%
scaler = StandardScaler()
item_uses_std = scaler.fit_transform(json_normalize(skilled_player_stats_informed["item_uses"].map(eval)
                                                   ).fillna(0)
                                    )
pca = PCA(n_components=10)

pca.fit_transform(item_uses_std)

pca.explained_variance_ratio_.sum()
# Out:
# 0.2627235603009467

# %% [markdown]
# ## Feature Engineering

# %%
neutral_cols = [col for col in json_normalize(skilled_player_stats_informed["damage_taken"].map(eval)
                                             ) if col.startswith('npc_dota_neutral')]

skilled_player_stats_informed["neutral_damage_taken"] = json_normalize(skilled_player_stats_informed["damage_taken"].map(eval)
                                                                      )[neutral_cols].sum(axis=1, skipna=True)
del neutral_cols

skilled_player_stats_informed["neutral_damage_taken"]
# Out:
# 0         741.0
# 1        4084.0
# 2          90.0
# 3         885.0
# 4         152.0
#          ...
# 7789      547.0
# 7790       15.0
# 7791      200.0
# 7792    11114.0
# 7793       98.0
# Name: neutral_damage_taken, Length: 7794, dtype: float64

# %%
bighist(skilled_player_stats_informed['neutral_damage_taken'], "Neutral Damage Taken")

# %% [markdown]
# * **Neutral Damage Taken** There is a column called "damage_taken", where it seems like there would be a lot of dimensionality, however, it can be filtered to only have columns containing neutral monsters, since there is a certain type of play style that will take a lot more damage from these neutral monsters than others, so I summed up all the values from these columns containing the damage taken from neutral monsters, and made them into one single column, called "neutral_damage_taken."

# %%
minion_cols = [col for col in json_normalize(skilled_player_stats_informed["damage"].map(eval)
                                            ) if col.startswith('npc_dota_creep')]

skilled_player_stats_informed['damage_to_minion'] = json_normalize(skilled_player_stats_informed["damage"].map(eval)
                                                                  )[minion_cols].sum(axis=1, skipna=True)
del minion_cols

skilled_player_stats_informed['damage_to_minion']
# Out:
# 0       104883.0
# 1        74089.0
# 2        28502.0
# 3        29334.0
# 4        59530.0
#           ...
# 7789     51681.0
# 7790     63349.0
# 7791     18518.0
# 7792     65655.0
# 7793    132553.0
# Name: damage_to_minion, Length: 7794, dtype: float64

# %%
bighist(skilled_player_stats_informed['damage_to_minion'], "Damage to Minion")

# %% [markdown]
# * **Damage to Minion** I created another feature in a similar way that I did with "neutral_damage_taken," except by how much damage a player does to enemy minions.

# %%
len(json_normalize(skilled_player_stats_informed["runes"].map(eval)
                  ).columns)
# Out:
# 7

# %%
skilled_player_stats_informed = pd.concat([
    skilled_player_stats_informed,
    json_normalize(skilled_player_stats_informed["runes"].map(eval)).add_prefix("rune_")
], axis=1)

# %%
len(json_normalize(skilled_player_stats_informed["killed_by"].map(eval)
                  ).columns)
# Out:
# 180

# %%
len(json_normalize(skilled_player_stats_informed["kill_streaks"].map(eval)
                  ).columns)
# Out:
# 8

# %%
len(json_normalize(skilled_player_stats_informed["multi_kills"].map(eval)
                  ).columns)
# Out:
# 4

# %%
skilled_player_stats_informed = pd.concat([
    skilled_player_stats_informed,
    json_normalize(skilled_player_stats_informed["kill_streaks"].map(eval)
                  ).add_prefix("kill_streak_"),
    json_normalize(skilled_player_stats_informed["multi_kills"].map(eval)
                  ).add_prefix("multi_kill_")
], axis=1)

# %% [markdown]
# ## Kill Streaks
# <img src="https://images-wixmp-ed30a86b8c4ca887773594c2.wixmp.com/f/57294127-a297-443a-851d-b9bbd48a7a13/d87pml9-8a31bf65-7f9c-4696-bab9-27a77c12c089.png/v1/fill/w_600,h_800,strp/dota_2_kill_streaks__and_weaver__by_phelan_velvel_d87pml9-fullview.png?token=eyJ0eXAiOiJKV1QiLCJhbGciOiJIUzI1NiJ9..NV-QmVvOW5FR6YxkZgK-QNk9lhQdum3xs47081qeB3k">

# %% [markdown]
# * **Kill Streak**: When a player kills another enemy player three times or more without dying. Once a 10 kill streak has been reached, they will continue to gain in this category, so it could also be seen as a 10+ kill streak.

# %% [markdown]
# ## Multi Kills
# <img src="https://gaming-tools.com/dota-2/wp-content/uploads/sites/10/2019/06/dota-2-kunkka-rampage.jpg">

# %% [markdown]
# * **Mult Kills**: This occurs when a player kills two or more players in a short window of time.

# %%
skilled_player_stats_informed = skilled_player_stats_informed.drop(
    columns=[
        "lane_pos", "obs", "sen", "purchase", "killed", "item_uses", 
        "ability_uses", "hero_hits", "damage", "damage_taken", 
        "damage_inflictor", "runes", "killed_by", "kill_streaks",
        "multi_kills", "gold_reasons", "xp_reasons", "skill"
    ]
).fillna(0)

# %% [markdown]
# ## Final Set of Features Before Clustering

# %%
skilled_player_stats_informed[skilled_player_stats_informed.columns[-56:]].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7794 entries, 0 to 7793
# Data columns (total 56 columns):
# item_0                  7794 non-null int64
# item_1                  7794 non-null int64
# item_2                  7794 non-null int64
# item_3                  7794 non-null int64
# item_4                  7794 non-null int64
# item_5                  7794 non-null int64
# kills                   7794 non-null int64
# deaths                  7794 non-null int64
# assists                 7794 non-null int64
# gold                    7794 non-null float64
# last_hits               7794 non-null int64
# denies                  7794 non-null int64
# gold_per_min            7794 non-null int64
# xp_per_min              7794 non-null int64
# gold_spent              7794 non-null float64
# hero_damage             7794 non-null float64
# tower_damage            7794 non-null float64
# hero_healing            7794 non-null float64
# level                   7794 non-null int64
# stuns                   7794 non-null float64
# pings                   7794 non-null float64
# gold_reasons_0          7794 non-null float64
# gold_reasons_1          7794 non-null float64
# gold_reasons_6          7794 non-null float64
# gold_reasons_11         7794 non-null float64
# gold_reasons_12         7794 non-null float64
# gold_reasons_13         7794 non-null int64
# gold_reasons_14         7794 non-null float64
# gold_reasons_2          7794 non-null float64
# gold_reasons_15         7794 non-null float64
# gold_reasons_5          7794 non-null float64
# xp_reasons_0            7794 non-null float64
# xp_reasons_1            7794 non-null float64
# xp_reasons_2            7794 non-null int64
# xp_reasons_3            7794 non-null float64
# neutral_damage_taken    7794 non-null float64
# damage_to_minion        7794 non-null float64
# rune_5                  7794 non-null float64
# rune_1                  7794 non-null float64
# rune_2                  7794 non-null float64
# rune_3                  7794 non-null float64
# rune_4                  7794 non-null float64
# rune_0                  7794 non-null float64
# rune_6                  7794 non-null float64
# kill_streak_3           7794 non-null float64
# kill_streak_4           7794 non-null float64
# kill_streak_5           7794 non-null float64
# kill_streak_6           7794 non-null float64
# kill_streak_7           7794 non-null float64
# kill_streak_8           7794 non-null float64
# kill_streak_9           7794 non-null float64
# kill_streak_10          7794 non-null float64
# multi_kill_2            7794 non-null float64
# multi_kill_3            7794 non-null float64
# multi_kill_4            7794 non-null float64
# multi_kill_5            7794 non-null float64
# dtypes: float64(40), int64(16)
# memory usage: 3.3 MB

# %% [markdown]
# ### K-Means: Clusters: 5

# %%
scaler = StandardScaler()
X_std = scaler.fit_transform(
    skilled_player_stats_informed.drop(
        columns=["match_id", "player_slot", "hero_id"]))

# %%
kmeans = KMeans(n_clusters=5, n_jobs=-1)

kmeans.fit(X_std)
# Out:
# KMeans(algorithm='auto', copy_x=True, init='k-means++', max_iter=300,
#        n_clusters=5, n_init=10, n_jobs=-1, precompute_distances='auto',
#        random_state=None, tol=0.0001, verbose=0)

# %%
y_pred = kmeans.predict(X_std)

# %% [markdown]
# ##### Silhouette Score:

# %%
print(metrics.silhouette_score(X_std, y_pred, metric='euclidean'))
# Out:
# 0.06528273133809644

# %% [markdown]
# #### Visualization

# %% [markdown]
# ##### PCA

# %%
pca = PCA(n_components=2)
# %time pca_results = pd.DataFrame(pca.fit_transform(X_std))
# Out:
# Wall time: 18.9 ms

# %%
plt.scatter(x=pca_results[0], y=pca_results[1], c=y_pred)
plt.colorbar()
plt.show()

# %% [markdown]
# ##### t-SNE:   perplexity=40, n_iter=300

# %%
tsne = TSNE(n_components=2, perplexity=40, n_iter=300, verbose=1)
# %time tsne_results = pd.DataFrame(tsne.fit_transform(X_std))
# Out:
# [t-SNE] Computing 121 nearest neighbors...
# [t-SNE] Indexed 7794 samples in 0.021s...
# [t-SNE] Computed neighbors for 7794 samples in 5.631s...
# [t-SNE] Computed conditional probabilities for sample 1000 / 7794
# [t-SNE] Computed conditional probabilities for sample 2000 / 7794
# [t-SNE] Computed conditional probabilities for sample 3000 / 7794
# [t-SNE] Computed conditional probabilities for sample 4000 / 7794
# [t-SNE] Computed conditional probabilities for sample 5000 / 7794
# [t-SNE] Computed conditional probabilities for sample 6000 / 7794
# [t-SNE] Computed conditional probabilities for sample 7000 / 7794
# [t-SNE] Computed conditional probabilities for sample 7794 / 7794
# [t-SNE] Mean sigma: 1.709958
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 86.543945
# [t-SNE] KL divergence after 300 iterations: 3.471501
# Wall time: 25.4 s

# %%
plt.scatter(x=tsne_results[0], y=tsne_results[1], c=y_pred)
plt.colorbar()
plt.show()

# %% [markdown]
# ##### UMAP: n_neighbors=15, min_dist=0.6

# %%
umap = UMAP(n_neighbors=15, min_dist=0.6)
# %time umap_results = pd.DataFrame(umap.fit_transform(X_std))
# Out:
# Wall time: 13.6 s

# %%
plt.scatter(x=umap_results[0], y=umap_results[1], c=y_pred)
plt.colorbar()
plt.show()

# %% [markdown]
# In terms of pure speed, K-Means wins, but I am not satisfied with the results. It mistook the far off outlier group discovered by UMAP to be a part of the closer lower part of the main cluster that is just starting to break away. This UMAP is promising, though.

# %% [markdown]
# ### Agglomerative: 5 Clusters

# %%
agg_cluster = AgglomerativeClustering(n_clusters=5)

y_pred = agg_cluster.fit_predict(X_std)

# %% [markdown]
# #### Silhouette Score:

# %%
print(metrics.silhouette_score(X_std, y_pred, metric='euclidean'))
# Out:
# 0.022524470671924212

# %% [markdown]
# #### Visualization

# %% [markdown]
# ##### PCA

# %%
plt.scatter(x=pca_results[0], y=pca_results[1], c=y_pred)
plt.colorbar()
plt.show()

# %% [markdown]
# #### t-SNE

# %%
plt.scatter(x=tsne_results[0], y=tsne_results[1], c=y_pred)
plt.colorbar()
plt.show()

# %% [markdown]
# #### UMAP

# %%
plt.scatter(x=umap_results[0], y=umap_results[1], c=y_pred)
plt.colorbar()
plt.show()

# %% [markdown]
# The UMAP and model agree that something is very odd about the cluster to the far left of the plot.

# %% [markdown]
# ### HDBSCAN: Minimum Cluster Size: 5

# %%
hdbscan = HDBSCAN(min_cluster_size=5)

y_pred = hdbscan.fit_predict(X_std)

# %% [markdown]
# #### Visualization

# %% [markdown]
# ##### PCA

# %%
plt.scatter(x=pca_results[0], y=pca_results[1], c=y_pred)
plt.colorbar()
plt.show()

# %% [markdown]
# #### t-SNE

# %%
plt.scatter(x=tsne_results[0], y=tsne_results[1], c=y_pred)
plt.colorbar()
plt.show()

# %% [markdown]
# #### UMAP

# %%
plt.scatter(x=umap_results[0], y=umap_results[1], c=y_pred)
plt.colorbar()
plt.show()

# %% [markdown]
# # Honing In
# <img src="https://steamcdn-a.akamaihd.net/apps/dota2/images/outlanders/header_void.png">

# %% [markdown]
# I found that agglomerative with UMAP had a good result of detecting outliers, while still adding further divisions on the main visualized group. Something I want to try now is to feed the UMAP into the Agglomerative clustering model and see if I can get better definition on the large cluster, while still retaining accurate clustering of the small anomaly group.

# %% [markdown]
# ## UMAP into Agglomerative

# %%
umap = UMAP(n_neighbors=20, min_dist=0.1)
# %time umap_results = pd.DataFrame(umap.fit_transform(X_std))
# Out:
# Wall time: 15.3 s

# %% [markdown]
# #### UMAP(n_neighbors=20, min_dist=0.1)

# %%
agg_cluster = AgglomerativeClustering(n_clusters=5, linkage="ward")

y_pred = agg_cluster.fit_predict(umap_results)

# %% [markdown]
# #### AgglomerativeClustering(n_clusters=5, linkage="ward")

# %%
# UMAP(n_neighbors=20, min_dist=0.1)
# AgglomerativeClustering(n_clusters=4, linkage="ward")
print(metrics.silhouette_score(umap_results, y_pred, metric='euclidean'))
# Out:
# 0.39006191

# %% [markdown]
# #### Silhouette Score:

# %%
# UMAP(n_neighbors=20, min_dist=0.1)
# AgglomerativeClustering(n_clusters=5, linkage="ward")
print(metrics.silhouette_score(umap_results, y_pred, metric='euclidean'))
# Out:
# 0.39651504

# %%
# UMAP(n_neighbors=20, min_dist=0.1)
# AgglomerativeClustering(n_clusters=6, linkage="ward")
print(metrics.silhouette_score(umap_results, y_pred, metric='euclidean'))
# Out:
# 0.38886502

# %% [markdown]
# # Now for the moment you've all been waiting for:

# %%
plt.figure(figsize=(18,12))
plt.scatter(x=umap_results[0], y=umap_results[1], c=y_pred)
plt.colorbar()
plt.show()

# %% [markdown]
# I feel satisfied with these results. I now have two clusters clearly divided from the rest of the larger main group, while the agglomerative clustering is still dividing the large group as well into three divisions, which would be helpful if I wanted to analyze those three player groups in more detail. However, I feel my time now is best spent on figuring out what makes the players in the two separated groups so different from the main cluster.

# %% [markdown]
# # Player Segmentation Analysis
# <img src="https://d1v4btv2rwszby.cloudfront.net/public/images/PF_LP_Dota_2_image.png">

# %%
skilled_player_stats_informed["cluster"] = y_pred

# %%
def melted_catplot(df, x_val, title):
    sns.catplot(
        data=df.melt(x_val, var_name="Legend", value_name="Count"),
        x=x_val,
        y="Count",
        hue="Legend",
        kind="bar",
        height=8,
        aspect=2.4,
    )
    plt.title(title)
    plt.show()

# %%
melted_catplot(
    skilled_player_stats_informed[
        ['denies', 'kills', 'deaths', 'assists',
         'level', 'stuns', 
         "cluster"]
    ],
    "cluster",
    "Basic Stats",
)

# %% [markdown]
# Cluster 2 and 4 are pretty similar, except that Cluster 4 is a better version of 2, since 4 has less assists (meaning they got more killing blows). Interesting that cluster 3 has the most assists, perhaps a support player?

# %%
melted_catplot(
    skilled_player_stats_informed[
        ['last_hits', 'gold_per_min', 'xp_per_min',
         "cluster"]
    ],
    "cluster",
    "Growth Stats",
)

# %% [markdown]
# These stats are all connected with how fast a player is able to accumulate experience and gold, last hitting an enemy unit or player grants more experience and gold. The same differences are apparent as in the previous plot. It seems like 0 and 3 are support oriented, while 1 is more of a versatile player.

# %%
melted_catplot(
    skilled_player_stats_informed[
        ['hero_healing', 'tower_damage', 
         'neutral_damage_taken', 
         'cluster']
    ],
    "cluster",
    "Other Stats",
)

# %% [markdown]
# Here is where cluster 3 is very different from the rest, with by far the most healing done. I would definitely call cluster 3 the "healer" player segment. 0 is fairly lackluster in these statistics, so players in this segment must contribute support in ways that do not show in the stats. I will refer to cluster 0 as "support".

# %%
melted_catplot(
    skilled_player_stats_informed[
        ['hero_damage', 'gold_spent', 'damage_to_minion', 
         'cluster']
    ],
    "cluster",
    "Damage Dealt and Gold Spent",
)

# %% [markdown]
# Nothing really interesting about this chart.

# %%
melted_catplot(
    skilled_player_stats_informed[
        ['kill_streak_3', 'kill_streak_4', 'kill_streak_5', 'kill_streak_6',
       'kill_streak_7', 'kill_streak_8', 'kill_streak_9', 'kill_streak_10', 'cluster']
    ],
    "cluster",
    "Kill Streaks",
)

# %% [markdown]
# This is definitely where cluster 2 and 4 really stand out. It's obvious cluster 4 is the "Hard-Carry", a player that starts out weak and vulnerable, but if they are able to stay alive long enough and gather gold and experience, they will be an unstoppable force that carries (thus the name) their team to victory. 2 would be what is called a Semi-Carry, where they are stronger more in the middle of the game, until they are then superceded in power by the Hard-Carry.

# %%
melted_catplot(
    skilled_player_stats_informed[
        ["multi_kill_2", "multi_kill_3", "multi_kill_4", "multi_kill_5", "cluster"]
    ],
    "cluster",
    "Multi Kills",
)

# %% [markdown]
# Here is where cluster 4: Hard-Carry really shines. The only one capable of wiping out the entire enemy team, and one of two capable of wiping out four at once, and the strongest at all other categories as well.

# %% [markdown]
# # Discussion
# <img src="https://go.overwolf.com/wp-content/uploads/2019/12/Feat-1-img.png">

# %% [markdown]
# Before going into analysis, I did not expect anything more than being able to clearly detect more than two distinct playstyles, but now I have been able to use clustering and dimensionality reduction to group players into 5 distinct groups.
#
# The findings from this research would be helpful firstly in helping video game developers to detect high performing players, and what character they were playing, as perhaps they may be playing a character that is overperforming, and need tweaking to bring a character into line with the rest of the lineup. Likewise, the same goes for underperforming characters that may need to be improved. Utilizing the UMAP, more unusual player behavior could be detected, where cheating may be involved, and then can be investigated more quickly when potentially detected.
#
# The time saved from gaining better insights from gameplay data to develop and further balance an existing game is invaluable. Moreover, quickly being able to react to cheating and investigate suspicious behavior allows for the rest of a game's playerbase to have a better experience, preventing customer churn.
#
# Also, this same approach can be applied to detecting fraudulent account transactions.

# %% [markdown]
# # Questions?
